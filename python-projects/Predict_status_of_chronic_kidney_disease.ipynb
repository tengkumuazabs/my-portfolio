# %% [markdown]
# <a href="https://colab.research.google.com/github/tengkumuazabs/my-portfolio/blob/main/python-projects/Predict_status_of_chronic_kidney_disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import gdown

# %%
# !gdown 19PgRhV9PqXKS08wZKk-fZWD8lIrW2pCD
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19PgRhV9PqXKS08wZKk-fZWD8lIrW2pCD
# To: /content/kidney_disease.csv
# 100% 48.6k/48.6k [00:00<00:00, 63.4MB/s]

# %%
df=pd.read_csv('kidney_disease.csv')

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (400, 26)

# %%
# renaming the columns

# %%
# !gdown 1j9s-ffXqfBWp-KGgPJ2a90T5Y4DVyu-t
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1j9s-ffXqfBWp-KGgPJ2a90T5Y4DVyu-t
# To: /content/data_description.txt
# 100% 502/502 [00:00<00:00, 1.80MB/s]

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
columns=pd.read_csv('data_description.txt',sep='-')

# %%
columns.head()
# Out:
#           1. Features:
# id                  id
# age                age
# bp      blood pressure
# sg    specific gravity
# al             albumin

# %%
columns=columns.reset_index()

# %%
columns.columns=['cols','abb_col_names']

# %%
columns.head()
# Out:
#    cols     abb_col_names
# 0   id                 id
# 1  age                age
# 2   bp     blood pressure
# 3   sg   specific gravity
# 4   al            albumin

# %%
columns.abb_col_names=columns.abb_col_names.replace(" ", "_",regex=True)

# %%
columns.head()
# Out:
#    cols     abb_col_names
# 0   id                 id
# 1  age                age
# 2   bp     blood_pressure
# 3   sg   specific_gravity
# 4   al            albumin

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.columns=columns.abb_col_names.values

# %%
df.head()
# Out:
#    id   age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0   0  48.0            80.0             1.020      1.0    0.0             NaN
# 1   1   7.0            50.0             1.020      4.0    0.0             NaN
# 2   2  62.0            80.0             1.010      2.0    3.0          normal
# 3   3  48.0            70.0             1.005      4.0    0.0          normal
# 4   4  51.0            80.0             1.010      2.0    0.0          normal
#
#   _pus_cell pus_cell_clumps    bacteria  ...  packed_cell_volume  \
# 0    normal      notpresent  notpresent  ...                  44
# 1    normal      notpresent  notpresent  ...                  38
# 2    normal      notpresent  notpresent  ...                  31
# 3  abnormal         present  notpresent  ...                  32
# 4    normal      notpresent  notpresent  ...                  35
#
#    white_blood_cell_count  red_blood_cell_count  ypertension  \
# ...

# %%
df.dtypes
# Out:
# id                           int64
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# _pus_cell                   object
# pus_cell_clumps             object
# bacteria                    object
# blood_glucose_random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume          object
# white_blood_cell_count      object
# red_blood_cell_count        object
# ypertension                 object
# diabetes_mellitus           object
# coronary_artery_disease     object
# appetite                    object
# pedal_edema                 object
# anemia                      object
# class                       object
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', '_pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'ypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'pedal_edema', 'anemia', 'class'],
#       dtype='object')

# %%
features=['red_blood_cell_count','packed_cell_volume','white_blood_cell_count']

# %%
def convert_type(df,features):
  df[features]=pd.to_numeric(df[features],errors='coerce')

# %%
for feature in features:
  convert_type(df,feature)

# %%
df.drop('id',axis=1,inplace=True)

# %%
# extract numerical and categorical features

# %%
def extract_cat_num(df):
  cat_col=[col for col in df.columns if df[col].dtype=='object']
  num_col=[col for col in df.columns if df[col].dtype!='object']
  return cat_col,num_col

# %%
cat_col,num_col=extract_cat_num(df)

# %%
cat_col
# Out:
# ['red_blood_cells',
#  '_pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'ypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'pedal_edema',
#  'anemia',
#  'class']

# %%
num_col
# Out:
# ['age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count',
#  'red_blood_cell_count']

# %%
for col in cat_col:
  print('{} has {} values \n'.format(col, df[col].unique()))
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values
#
# _pus_cell has ['normal' 'abnormal' nan] values
#
# pus_cell_clumps has ['notpresent' 'present' nan] values
#
# bacteria has ['notpresent' 'present' nan] values
#
# ypertension has ['yes' 'no' nan] values
#
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# coronary_artery_disease has ['no' 'yes' '\tno' nan] values
#
# appetite has ['good' 'poor' nan] values
#
# pedal_edema has ['no' 'yes' nan] values
#
# anemia has ['no' 'yes' nan] values
#
# class has ['ckd' 'ckd\t' 'notckd'] values

# %%
df.diabetes_mellitus.replace(to_replace={'\tno':'no','\tyes':'yes'},inplace=True)
df.coronary_artery_disease.replace('\tno','no',inplace=True)
df['class'].replace('ckd\t','ckd',inplace=True)

# %%
for col in cat_col:
  print('{} has {} values \n'.format(col, df[col].unique()))
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values
#
# _pus_cell has ['normal' 'abnormal' nan] values
#
# pus_cell_clumps has ['notpresent' 'present' nan] values
#
# bacteria has ['notpresent' 'present' nan] values
#
# ypertension has ['yes' 'no' nan] values
#
# diabetes_mellitus has ['yes' 'no' ' yes' nan] values
#
# coronary_artery_disease has ['no' 'yes' nan] values
#
# appetite has ['good' 'poor' nan] values
#
# pedal_edema has ['no' 'yes' nan] values
#
# anemia has ['no' 'yes' nan] values
#
# class has ['ckd' 'notckd'] values

# %%
len(num_col)
# Out:
# 14

# %%
# checking features distributons

# %%
plt.figure(figsize=(30,20))

for i,feature in enumerate(num_col):
  plt.subplot(5,3,i+1)
  df[feature].hist()
  plt.title(feature)

# %% [markdown]
# observation results:
# - age looks like a bit left skewed
# - blood glucose random is right skewed
# - blood urea is also a bit right skewed
# - rest of the features are lightly skewed

# %%
# checking the label distribution for categorical data

# %%
len(cat_col)
# Out:
# 11

# %%
df.anemia.isna().sum()
# Out:
# 1

# %%
df.dropna()
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 9    53.0            90.0             1.020      2.0    0.0        abnormal
# 11   63.0            70.0             1.010      3.0    0.0        abnormal
# 14   68.0            80.0             1.010      3.0    2.0          normal
# 20   61.0            80.0             1.015      2.0    0.0        abnormal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
df['anemia'].dropna()
# Out:
# 0       no
# 1       no
# 2      yes
# 3      yes
# 4       no
#       ...
# 395     no
# 396     no
# 397     no
# 398     no
# 399     no
# Name: anemia, Length: 399, dtype: object

# %%
sns.countplot(x='anemia', data=df.anemia.dropna().reset_index())
# Out:
# <Axes: xlabel='anemia', ylabel='count'>

# %%
plt.figure(figsize=(20,20))

for i,feature in enumerate(cat_col):
  print(feature)
  plt.subplot(4,3,i+1)
  sns.countplot(x=feature, data=df[feature].dropna().reset_index())
# Out:
# red_blood_cells
# _pus_cell
# pus_cell_clumps
# bacteria
# ypertension
# diabetes_mellitus
# coronary_artery_disease
# appetite
# pedal_edema
# anemia
# class

# %% [markdown]
# a few features have imbalanced distribution of categories. stratified folds will be necessary while cross validation.

# %%
sns.countplot(x='class',data=df)
plt.xlabel('class')
plt.ylabel('count')
plt.title('target class')
# Out:
# Text(0.5, 1.0, 'target class')

# %%
# correlations

# %%
plt.figure(figsize=(10,8))
corr=df.corr()
sns.heatmap(corr,annot=True)
# Out:
# <ipython-input-48-b866e9731ca5>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
# <Axes: >

# %%
df.groupby(['red_blood_cells','class']).red_blood_cell_count.agg(['count','mean','median','min','max'])
# Out:
#                         count      mean  median  min  max
# red_blood_cells class
# abnormal        ckd        25  3.832000     3.7  2.5  5.6
# normal          ckd        40  3.782500     3.8  2.1  8.0
#                 notckd    134  5.368657     5.3  4.4  6.5

# %%
# check for positive correlation and its impact on classes

# %%
import plotly.express as px

# %%
px.violin(df,x='class',y='red_blood_cell_count',color='class')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(df,'haemoglobin','packed_cell_volume')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
grid=sns.FacetGrid(df,hue='class',aspect=2)
grid.map(sns.kdeplot,'red_blood_cell_count')
grid.add_legend()

# %% [markdown]
# both distributions are quite different, distribution CKD is quite normal and evenly distributed but not CKD because its distribution is a little bit left-skewed but quite close to a normal distribution

# %%
def violin(col):
  fig=px.violin(df,y=col,x='class',color='class',box=True)
  return fig.show()

def scatters(col1,col2):
  fig=px.scatter(df,x=col1,y=col2,color='class')
  return fig.show()

# %%
def kde_plot(feature):
  grid=sns.FacetGrid(df,hue='class',aspect=2)
  grid.map(sns.kdeplot,feature)
  grid.add_legend()

# %%
kde_plot('red_blood_cell_count')

# %%
kde_plot('haemoglobin')

# %%
scatters('red_blood_cell_count', 'packed_cell_volume')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
scatters('red_blood_cell_count','haemoglobin')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# rbccount range approx 2 to < 4.5 and haemoglobin between 3 and < 13 are mostly classified as ckd
#
# rbccount range > 4.5 to approx 6.1 and haemoglobin between > 13 to 17.8 are classified as notckd

# %%
violin('red_blood_cell_count')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
violin('packed_cell_volume')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# check for negative correlation and its impact on classes

# %% [markdown]
# albumin, blood urea -> red blood cell count, packed cell volume, haemoglobin

# %%
scatters('red_blood_cell_count','albumin')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# albumin levels above 0 affect ckd obviously

# %%
scatters('packed_cell_volume','blood_urea')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# packed cell volume >= 49 largely affects to be non ckd

# %%
fig=px.bar(df,x='specific_gravity',y='packed_cell_volume',
           color='class',barmode='group',height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# specific gravity >= 1.02 affects notckd

# %%
df.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0             NaN
# 1   7.0            50.0             1.020      4.0    0.0             NaN
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
# 4  51.0            80.0             1.010      2.0    0.0          normal
#
#   _pus_cell pus_cell_clumps    bacteria  blood_glucose_random  ...  \
# 0    normal      notpresent  notpresent                 121.0  ...
# 1    normal      notpresent  notpresent                   NaN  ...
# 2    normal      notpresent  notpresent                 423.0  ...
# 3  abnormal         present  notpresent                 117.0  ...
# 4    normal      notpresent  notpresent                 106.0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# red_blood_cells            152
# red_blood_cell_count       131
# white_blood_cell_count     106
# potassium                   88
# sodium                      87
# packed_cell_volume          71
# _pus_cell                   65
# haemoglobin                 52
# sugar                       49
# specific_gravity            47
# albumin                     46
# blood_glucose_random        44
# blood_urea                  19
# serum_creatinine            17
# blood_pressure              12
# age                          9
# bacteria                     4
# pus_cell_clumps              4
# ypertension                  2
# diabetes_mellitus            2
# coronary_artery_disease      2
# appetite                     1
# pedal_edema                  1
# anemia                       1
# class                        0
# dtype: int64

# %%
cat_col
# Out:
# ['red_blood_cells',
#  '_pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'ypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'pedal_edema',
#  'anemia',
#  'class']

# %%
sns.countplot(x=df.red_blood_cells, data=df.dropna().reset_index())
# Out:
# <Axes: xlabel='red_blood_cells', ylabel='count'>

# %%
data=df.copy()

# %%
# random value imputation

# %%
data.red_blood_cells.isnull().sum()
# Out:
# 152

# %%
data.red_blood_cells.dropna().sample()
# Out:
# 146    abnormal
# Name: red_blood_cells, dtype: object

# %%
random_sample=data.red_blood_cells.dropna().sample(data.red_blood_cells.isnull().sum())

# %%
random_sample
# Out:
# 282      normal
# 195    abnormal
# 272      normal
# 396      normal
# 323      normal
#          ...
# 215      normal
# 311      normal
# 212      normal
# 354      normal
# 54       normal
# Name: red_blood_cells, Length: 152, dtype: object

# %%
random_sample.index
# Out:
# Int64Index([282, 195, 272, 396, 323, 352, 391,  22, 357, 340,
#             ...
#             304, 342, 161,  56, 324, 215, 311, 212, 354,  54],
#            dtype='int64', length=152)

# %%
data[data.red_blood_cells.isnull()].index
# Out:
# Int64Index([  0,   1,   5,   6,  10,  12,  13,  15,  16,  17,
#             ...
#             245, 268, 280, 290, 295, 309, 322, 349, 350, 381],
#            dtype='int64', length=152)

# %%
random_sample.index=data[data.red_blood_cells.isnull()].index

# %%
random_sample.index
# Out:
# Int64Index([  0,   1,   5,   6,  10,  12,  13,  15,  16,  17,
#             ...
#             245, 268, 280, 290, 295, 309, 322, 349, 350, 381],
#            dtype='int64', length=152)

# %%
random_sample
# Out:
# 0        normal
# 1      abnormal
# 5        normal
# 6        normal
# 10       normal
#          ...
# 309      normal
# 322      normal
# 349      normal
# 350      normal
# 381      normal
# Name: red_blood_cells, Length: 152, dtype: object

# %%
data.loc[data.red_blood_cells.isnull(),'red_blood_cells']
# Out:
# Series([], Name: red_blood_cells, dtype: object)

# %%
data.loc[data.red_blood_cells.isnull(),'red_blood_cells']=random_sample

# %%
data.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0          normal
# 1   7.0            50.0             1.020      4.0    0.0        abnormal
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
# 4  51.0            80.0             1.010      2.0    0.0          normal
#
#   _pus_cell pus_cell_clumps    bacteria  blood_glucose_random  ...  \
# 0    normal      notpresent  notpresent                 121.0  ...
# 1    normal      notpresent  notpresent                   NaN  ...
# 2    normal      notpresent  notpresent                 423.0  ...
# 3  abnormal         present  notpresent                 117.0  ...
# 4    normal      notpresent  notpresent                 106.0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# ...

# %%
sns.countplot(x=data.red_blood_cells,data=data.dropna().reset_index())
# Out:
# <Axes: xlabel='red_blood_cells', ylabel='count'>

# %%
data.red_blood_cells.value_counts()/len(data)
# Out:
# normal      0.8
# abnormal    0.2
# Name: red_blood_cells, dtype: float64

# %%
def random_value_imputation(feature):
  random_sample=data[feature].dropna().sample(data[feature].isnull().sum())
  random_sample.index=data[data[feature].isnull()].index
  data.loc[data[feature].isnull(),feature]=random_sample

# %%
data.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', '_pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'ypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'pedal_edema', 'anemia', 'class'],
#       dtype='object')

# %%
random_value_imputation('_pus_cell')
random_value_imputation('red_blood_cells')

# %%
data[cat_col].isnull().sum()
# Out:
# red_blood_cells            0
# _pus_cell                  0
# pus_cell_clumps            4
# bacteria                   4
# ypertension                2
# diabetes_mellitus          2
# coronary_artery_disease    2
# appetite                   1
# pedal_edema                1
# anemia                     1
# class                      0
# dtype: int64

# %%
mode=data['pus_cell_clumps'].mode()[0]
mode
# Out:
# 'notpresent'

# %%
data['pus_cell_clumps']=data['pus_cell_clumps'].fillna(mode)

# %%
def impute_mode(feature):
  mode=data[feature].mode()[0]
  data[feature]=data[feature].fillna(mode)

# %%
for col in cat_col:
  impute_mode(col)

# %%
data[cat_col].isnull().sum()
# Out:
# red_blood_cells            0
# _pus_cell                  0
# pus_cell_clumps            0
# bacteria                   0
# ypertension                0
# diabetes_mellitus          0
# coronary_artery_disease    0
# appetite                   0
# pedal_edema                0
# anemia                     0
# class                      0
# dtype: int64

# %%
data[num_col].isnull().sum()
# Out:
# age                         9
# blood_pressure             12
# specific_gravity           47
# albumin                    46
# sugar                      49
# blood_glucose_random       44
# blood_urea                 19
# serum_creatinine           17
# sodium                     87
# potassium                  88
# haemoglobin                52
# packed_cell_volume         71
# white_blood_cell_count    106
# red_blood_cell_count      131
# dtype: int64

# %%
for col in num_col:
  random_value_imputation(col)

# %%
data[num_col].isnull().sum()
# Out:
# age                       0
# blood_pressure            0
# specific_gravity          0
# albumin                   0
# sugar                     0
# blood_glucose_random      0
# blood_urea                0
# serum_creatinine          0
# sodium                    0
# potassium                 0
# haemoglobin               0
# packed_cell_volume        0
# white_blood_cell_count    0
# red_blood_cell_count      0
# dtype: int64

# %%
# feature encoding

# %%
for col in cat_col:
  print('{} has {} categories'.format(col,data[col].nunique()))
# Out:
# red_blood_cells has 2 categories
# _pus_cell has 2 categories
# pus_cell_clumps has 2 categories
# bacteria has 2 categories
# ypertension has 2 categories
# diabetes_mellitus has 3 categories
# coronary_artery_disease has 2 categories
# appetite has 2 categories
# pedal_edema has 2 categories
# anemia has 2 categories
# class has 2 categories

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for col in cat_col:
  data[col]=le.fit_transform(data[col])

# %%
data.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar  red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0                1
# 1   7.0            50.0             1.020      4.0    0.0                0
# 2  62.0            80.0             1.010      2.0    3.0                1
# 3  48.0            70.0             1.005      4.0    0.0                1
# 4  51.0            80.0             1.010      2.0    0.0                1
#
#    _pus_cell  pus_cell_clumps  bacteria  blood_glucose_random  ...  \
# 0          1                0         0                 121.0  ...
# 1          1                0         0                 308.0  ...
# 2          1                0         0                 423.0  ...
# 3          0                1         0                 117.0  ...
# 4          1                0         0                 106.0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# ...

# %%
# feature importance

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
ind_col=[col for col in data.columns if col != 'class']
dep_col='class'

# %%
x=data[ind_col]
y=data[dep_col]

# %%
ordered_rank_features=SelectKBest(score_func=chi2,k=20)
ordered_feature=ordered_rank_features.fit(x,y)

# %%
ordered_feature
# Out:
# SelectKBest(k=20, score_func=<function chi2 at 0x7aa790048550>)

# %%
ordered_feature.scores_
# Out:
# array([1.15460947e+02, 7.72053211e+01, 5.56807143e-03, 2.31095761e+02,
#        9.55792593e+01, 1.12133333e+01, 1.55463203e+01, 2.52000000e+01,
#        1.32000000e+01, 2.34707201e+03, 2.40894376e+03, 3.62699538e+02,
#        2.80573576e+01, 3.39722231e+00, 1.16981203e+02, 3.38732166e+02,
#        1.80728477e+04, 2.39533276e+01, 8.82000000e+01, 2.04392523e+01,
#        2.04000000e+01, 4.92000000e+01, 4.56000000e+01, 3.60000000e+01])

# %%
datascores=pd.DataFrame(ordered_feature.scores_,columns=['score'])
datascores
# Out:
#            score
# 0     115.460947
# 1      77.205321
# 2       0.005568
# 3     231.095761
# 4      95.579259
# 5      11.213333
# 6      15.546320
# 7      25.200000
# 8      13.200000
# 9    2347.072008
# 10   2408.943757
# 11    362.699538
# 12     28.057358
# 13      3.397222
# 14    116.981203
# 15    338.732166
# 16  18072.847694
# 17     23.953328
# 18     88.200000
# 19     20.439252
# 20     20.400000
# 21     49.200000
# 22     45.600000
# 23     36.000000

# %%
x.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', '_pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'ypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'pedal_edema', 'anemia'],
#       dtype='object')

# %%
dfcolumns=pd.DataFrame(x.columns)
dfcolumns
# Out:
#                           0
# 0                       age
# 1            blood_pressure
# 2          specific_gravity
# 3                   albumin
# 4                     sugar
# 5           red_blood_cells
# 6                 _pus_cell
# 7           pus_cell_clumps
# 8                  bacteria
# 9      blood_glucose_random
# 10               blood_urea
# 11         serum_creatinine
# 12                   sodium
# 13                potassium
# 14              haemoglobin
# 15       packed_cell_volume
# 16   white_blood_cell_count
# 17     red_blood_cell_count
# 18              ypertension
# 19        diabetes_mellitus
# 20  coronary_artery_disease
# 21                 appetite
# 22              pedal_edema
# 23                   anemia

# %%
features_rank=pd.concat([dfcolumns,datascores],axis=1)

# %%
features_rank
# Out:
#                           0         score
# 0                       age    115.460947
# 1            blood_pressure     77.205321
# 2          specific_gravity      0.005568
# 3                   albumin    231.095761
# 4                     sugar     95.579259
# 5           red_blood_cells     11.213333
# 6                 _pus_cell     15.546320
# 7           pus_cell_clumps     25.200000
# 8                  bacteria     13.200000
# 9      blood_glucose_random   2347.072008
# 10               blood_urea   2408.943757
# 11         serum_creatinine    362.699538
# 12                   sodium     28.057358
# 13                potassium      3.397222
# 14              haemoglobin    116.981203
# 15       packed_cell_volume    338.732166
# 16   white_blood_cell_count  18072.847694
# 17     red_blood_cell_count     23.953328
# 18              ypertension     88.200000
# 19        diabetes_mellitus     20.439252
# 20  coronary_artery_disease     20.400000
# ...

# %%
features_rank.columns=['features','score']
features_rank
# Out:
#                    features         score
# 0                       age    115.460947
# 1            blood_pressure     77.205321
# 2          specific_gravity      0.005568
# 3                   albumin    231.095761
# 4                     sugar     95.579259
# 5           red_blood_cells     11.213333
# 6                 _pus_cell     15.546320
# 7           pus_cell_clumps     25.200000
# 8                  bacteria     13.200000
# 9      blood_glucose_random   2347.072008
# 10               blood_urea   2408.943757
# 11         serum_creatinine    362.699538
# 12                   sodium     28.057358
# 13                potassium      3.397222
# 14              haemoglobin    116.981203
# 15       packed_cell_volume    338.732166
# 16   white_blood_cell_count  18072.847694
# 17     red_blood_cell_count     23.953328
# 18              ypertension     88.200000
# 19        diabetes_mellitus     20.439252
# 20  coronary_artery_disease     20.400000
# ...

# %%
features_rank.nlargest(10,'score')
# Out:
#                   features         score
# 16  white_blood_cell_count  18072.847694
# 10              blood_urea   2408.943757
# 9     blood_glucose_random   2347.072008
# 11        serum_creatinine    362.699538
# 15      packed_cell_volume    338.732166
# 3                  albumin    231.095761
# 14             haemoglobin    116.981203
# 0                      age    115.460947
# 4                    sugar     95.579259
# 18             ypertension     88.200000

# %%
selected_columns=features_rank.nlargest(10,'score').features.values

# %%
selected_columns
# Out:
# array(['white_blood_cell_count', 'blood_urea', 'blood_glucose_random',
#        'serum_creatinine', 'packed_cell_volume', 'albumin', 'haemoglobin',
#        'age', 'sugar', 'ypertension'], dtype=object)

# %%
x_new=data[selected_columns]

# %%
# model building

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_new,y,train_size=0.75)

# %%
x_train.shape
# Out:
# (300, 10)

# %%
x_test.shape
# Out:
# (100, 10)

# %%
y_train.value_counts()
# Out:
# 0    185
# 1    115
# Name: class, dtype: int64

# %%
from xgboost import XGBClassifier

# %%
XGBClassifier()
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
param={
    'learning_rate':[0.05,0.2,0.25],
    'max_depth':[5,8,10,12],
    'min_child_weight':[1,3,5,7],
    'gamma':[0,0.1,0.2,0.4],
    'colsample_bytree':[0.3,0.4,0.7]
}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
clf=XGBClassifier()

# %%
import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %%
random_search=RandomizedSearchCV(clf, param_distributions=param,n_iter=5,
                                 scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)

# %%
random_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
# ...

# %%
random_search.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.3, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.25, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
random_search.best_params_
# Out:
# {'min_child_weight': 1,
#  'max_depth': 5,
#  'learning_rate': 0.25,
#  'gamma': 0,
#  'colsample_bytree': 0.3}

# %%
clf=random_search.best_estimator_

# %%
clf.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.3, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.25, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
cm=confusion_matrix(y_test,y_pred)
print('cm:')
print(cm)
# Out:
# cm:
# [[64  1]
#  [ 2 33]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.97
