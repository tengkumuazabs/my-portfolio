# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# read data for analysis

# %%
data = pd.read_csv(r'data/zomato.csv')

# %%
data.head(3)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
#
#                                              address             name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...            Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...   Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...  San Churro Cafe
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
# 2          Yes         No  3.8/5    918                  +91 9663487993
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
data.shape
# Out:
# (51717, 17)

# %%
# performing data preprocessing

# %%
data.duplicated().sum() #no duplicates
# Out:
# np.int64(0)

# %%
data.isna().sum() #null values detected
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
# clean null values

# %%
# delete row based on location column since it has few null values
data.dropna(subset=['location'], inplace=True)

# %%
df = data.copy()

# %%
df.location
# Out:
# 0                      Banashankari
# 1                      Banashankari
# 2                      Banashankari
# 3                      Banashankari
# 4                      Basavanagudi
#                     ...
# 51712                    Whitefield
# 51713                    Whitefield
# 51714                    Whitefield
# 51715    ITPL Main Road, Whitefield
# 51716    ITPL Main Road, Whitefield
# Name: location, Length: 51696, dtype: object

# %%
# add details to the location in order to get more accurate coordinates (all locations are located in Bangalore, Karnataka, India)
df.location = df.location + ' , Bangalore, Karnataka, India'

# %%
df.location
# Out:
# 0               Banashankari , Bangalore, Karnataka, India
# 1               Banashankari , Bangalore, Karnataka, India
# 2               Banashankari , Bangalore, Karnataka, India
# 3               Banashankari , Bangalore, Karnataka, India
# 4               Basavanagudi , Bangalore, Karnataka, India
#                                ...
# 51712             Whitefield , Bangalore, Karnataka, India
# 51713             Whitefield , Bangalore, Karnataka, India
# 51714             Whitefield , Bangalore, Karnataka, India
# 51715    ITPL Main Road, Whitefield , Bangalore, Karnat...
# 51716    ITPL Main Road, Whitefield , Bangalore, Karnat...
# Name: location, Length: 51696, dtype: object

# %%
df.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
# extract latitudes and longitudes from the data

# %%
locations = pd.DataFrame()

# %%
locations['Name'] = df.location.unique()

# %%
locations
# Out:
#                                                 Name
# 0         Banashankari , Bangalore, Karnataka, India
# 1         Basavanagudi , Bangalore, Karnataka, India
# 2          Mysore Road , Bangalore, Karnataka, India
# 3            Jayanagar , Bangalore, Karnataka, India
# 4   Kumaraswamy Layout , Bangalore, Karnataka, India
# ..                                               ...
# 88      West Bangalore , Bangalore, Karnataka, India
# 89         Magadi Road , Bangalore, Karnataka, India
# 90           Yelahanka , Bangalore, Karnataka, India
# 91      Sahakara Nagar , Bangalore, Karnataka, India
# 92              Peenya , Bangalore, Karnataka, India
#
# [93 rows x 1 columns]

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent='app', timeout=None)

# %%
lat, lon = [], []

# %%
for name in locations.Name:
    loc = geolocator.geocode(name)

    if loc is None:
        lat.append(np.nan)
        lon.append(np.nan)
    else:
        lat.append(loc.latitude)
        lon.append(loc.longitude)

# %%
locations['lat'] = lat
locations['lon'] = lon

# %%
locations
# Out:
#                                                 Name        lat        lon
# 0         Banashankari , Bangalore, Karnataka, India  12.939333  77.553982
# 1         Basavanagudi , Bangalore, Karnataka, India  12.941726  77.575502
# 2          Mysore Road , Bangalore, Karnataka, India  12.960171  77.556525
# 3            Jayanagar , Bangalore, Karnataka, India  12.939904  77.582638
# 4   Kumaraswamy Layout , Bangalore, Karnataka, India  12.906768  77.559502
# ..                                               ...        ...        ...
# 88      West Bangalore , Bangalore, Karnataka, India  13.009652  77.553054
# 89         Magadi Road , Bangalore, Karnataka, India  12.975608  77.555356
# 90           Yelahanka , Bangalore, Karnataka, India  13.107915  77.585524
# 91      Sahakara Nagar , Bangalore, Karnataka, India  13.062147  77.580061
# 92              Peenya , Bangalore, Karnataka, India  13.032981  77.533180
#
# [93 rows x 3 columns]

# %%
locations.isna().sum()
# Out:
# Name    0
# lat     2
# lon     2
# dtype: int64

# %%
locations[locations.lat.isna()]
# Out:
#                                              Name  lat  lon
# 79  Rammurthy Nagar , Bangalore, Karnataka, India  NaN  NaN
# 85   Sadashiv Nagar , Bangalore, Karnataka, India  NaN  NaN

# %%
# fill this empty lat and lon manually
locations.lat[79] = 13.0163
locations.lon[79] = 77.6785

locations.lat[85] = 13.0068
locations.lon[85] = 77.5813
# Out:
# C:\Users\modern14\AppData\Local\Temp\ipykernel_3624\2163290157.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   locations.lat[79] = 13.0163
# C:\Users\modern14\AppData\Local\Temp\ipykernel_3624\2163290157.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locations.lat[79] = 13.0163
# C:\Users\modern14\AppData\Local\Temp\ipykernel_3624\2163290157.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   locations.lon[79] = 77.6785
# C:\Users\modern14\AppData\Local\Temp\ipykernel_3624\2163290157.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locations.lon[79] = 77.6785
# C:\Users\modern14\AppData\Local\Temp\ipykernel_3624\2163290157.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   locations.lat[85] = 13.0068
# C:\Users\modern14\AppData\Local\Temp\ipykernel_3624\2163290157.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locations.lat[85] = 13.0068
# C:\Users\modern14\AppData\Local\Temp\ipykernel_3624\2163290157.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   locations.lon[85] = 77.5813
# C:\Users\modern14\AppData\Local\Temp\ipykernel_3624\2163290157.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locations.lon[85] = 77.5813

# %%
locations[locations.lat.isna()]
# Out:
# Empty DataFrame
# Columns: [Name, lat, lon]
# Index: []

# %%
# where are most number of restaurants located in Bangalore

# %%
df.location.value_counts()[0:10]
# Out:
# location
# BTM , Bangalore, Karnataka, India                      5124
# HSR , Bangalore, Karnataka, India                      2523
# Koramangala 5th Block , Bangalore, Karnataka, India    2504
# JP Nagar , Bangalore, Karnataka, India                 2235
# Whitefield , Bangalore, Karnataka, India               2144
# Indiranagar , Bangalore, Karnataka, India              2083
# Jayanagar , Bangalore, Karnataka, India                1926
# Marathahalli , Bangalore, Karnataka, India             1846
# Bannerghatta Road , Bangalore, Karnataka, India        1630
# Bellandur , Bangalore, Karnataka, India                1286
# Name: count, dtype: int64

# %%
df.location.value_counts()[0:10].plot(kind='bar')
# Out:
# <Axes: xlabel='location'>

# %%
# visualize using heatmap

# %%
locations_count = df.location.value_counts().reset_index()
locations_count.columns = ['Name', 'count']

# %%
locations_merged = locations.merge(locations_count, on='Name')

# %%
import folium

# %%
def genereteBaseMap():
    basemap = folium.Map(location=[12.97, 77.59])
    return basemap

# %%
basemap = genereteBaseMap()

# %%
from folium.plugins import HeatMap

# %%
HeatMap(locations_merged[['lat', 'lon', 'count']]).add_to(basemap)

# %%
basemap #majority of restaurants are located in city center
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44baeab163bbc06def7cac1694474bf6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44baeab163bbc06def7cac1694474bf6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44baeab163bbc06def7cac1694474bf6 = L.map(
#                 &quot;map_44baeab163bbc06def7cac1694474bf6&quot;,
#                 {
#                     center: [12.97, 77.59],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e4f1e7d14d0a845e6d69452d479e51f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3
287106, 77.57822478581892, 139.0], [12.982242261028464, 77.60826495187648, 370.0], [12.9934283, 77.5902145, 295.0], [13.0358698, 77.6323597, 153.0], [12.9624669, 77.6381958, 496.0], [12.9427087, 77.6307137, 439.0], [12.9678074, 77.6568367, 272.0], [12.983486268599062, 77.63905809493075, 22.0], [13.0027353, 77.5703253, 725.0], [12.9931876, 77.5753419, 165.0], [13.0093455, 77.6377094, 648.0], [12.9390255, 77.6238477, 1156.0], [12.9783547, 77.5728609, 155.0], [12.957998, 77.6037312, 27.0], [12.97339325, 77.61124684880099, 8.0], [12.9578658, 77.6958748, 76.0], [12.96381425, 77.72243691580387, 658.0], [12.9876393, 77.7377718, 113.0], [12.9592202, 77.7462921, 117.0], [13.007516, 77.695935, 18.0], [12.9243692, 77.6242433, 102.0], [12.9282918, 77.6254034, 216.0], [12.947945899082507, 77.64073420117386, 48.0], [12.961198894117535, 77.60650758548101, 102.0], [13.0005232, 77.5496166, 591.0], [13.0058357, 77.6281321, 664.0], [13.0439323, 77.6254268017299, 14.0], [13.0422794, 77.6248577, 187.0], [13.0258087, 77.6305067, 161.0], [13.0221416, 77.6403368, 853.0], [13.028605720818474, 77.57123576086566, 649.0], [13.0784743, 77.6068938, 3.0], [13.0163, 77.6785, 32.0], [12.973936, 77.6509982, 194.0], [12.9846713, 77.6790908, 101.0], [13.0382184, 77.5919, 14.0], [12.9176571, 77.4837568, 9.0], [12.99378735117383, 77.58515115082001, 27.0], [13.0068, 77.5813, 63.0], [12.99118045, 77.54489175084052, 191.0], [13.02383, 77.5529215, 119.0], [13.0096524, 77.5530535343493, 6.0], [12.975608,

# %%
# plotting all the markers

# %%
m = genereteBaseMap()

# %%
for index, row in locations_merged.iterrows():
    folium.Marker(location=[row['lat'], row['lon']], popup=row['count']).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_824e44ea768c1555be91e0c954fa4f62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_824e44ea768c1555be91e0c954fa4f62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_824e44ea768c1555be91e0c954fa4f62 = L.map(
#                 &quot;map_824e44ea768c1555be91e0c954fa4f62&quot;,
#                 {
#                     center: [12.97, 77.59],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_54bb13b541ca699391695fb952cd699f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_54bb13b541ca699391695fb952cd699f.addTo(map_824e44ea768c1555be91e0c954fa4f62);
#
#
#             var marker_82348eb0d8a7d7deb8fb03c8addf61a7 = L.marker(
#                 [12.9393328, 77.5539819],
#                 {
# }
#             ).addTo(map_824e44ea768c1555be91e0c954fa4f62);
#
#
#         var popup_071e86fb1a60169ceead969d731176d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16f1de7cba5cec783ce59a452d259836 = $(`&lt;div id=&quot;html_16f1de7cba5cec783ce59a452d259836&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;906&lt;/div&gt;`)[0];
#                 popup_071e86fb1a60169ceead969d731176d9.setContent(html_16f1de7cba5cec783ce59a452d259836);
#
#
#
#         marker_82348eb0d8a7d7deb8fb03c8addf61a7.bindPopup(popup_071e86fb1a60169ceead969d731176d9)
#         ;
#
#
#
#
#             var marker_92999e2aaaa4177af9ef05331cf62876 = L.marker(
#                 [12.9417261, 77.5755021],
#                 {
# }
#             ).addTo(map_824e44ea768c1555be91e0c954fa4f62);
#
#
#         var popup_959cb2fbbe1eff9b2454caa1ed39f14d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e73829161bec37f98a94e42534b67c5c = $(`&lt;div id=&quot;html_e73829161bec37f98a94e42534b67c5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;684&lt;/div&gt;`)[0];
#                 popup_959cb2fbbe1eff9b2454caa1ed39f14d.setContent(html_e73829161bec37f98a94e42534b67c5c);
#
#
#
#         marker_92999e2aaaa4177af9ef05331cf62876.bindPopup(popup_959cb2fbbe1eff9b2454caa1ed39f14d)
#         ;
#
#
#
#
#             var marker_0b996e73ba563fa3fd6befda5281817e = L.marker(
#                 [12.960171397033719, 77.55652496070614],
#                 {
# }
#             ).addTo(map_824e44ea768c1555be91e0c954fa4f62);
#
#
#         var popup_18982df2feab92faa8f7beb2cf432230 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6e8c4a471460cae6836be86e56bf567 = $(`&lt;div id=&quot;html_a6e8c4a471460cae6836be86e56bf567&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;22&lt;/div&gt;`)[0];
#                 popup_18982df2feab92faa8f7beb2cf432230.setContent(html_a6e8c4a471460cae6836be86e56bf567);
#
#
#
#         marker_0b996e73ba563fa3fd6befda5281817e.bindPopup(popup_18982df2feab92faa8f7beb2cf432230)
#         ;
#
#
#
#
#             var marker_3a6d745c915c94f1b1058129cb30a471 = L.marker(
#                 [12.9399039, 77.5826382],
#                 {
# }
#             ).addTo(map_824e44ea768c1555be91e0c954fa4f62);
#
#
#         var popup_375731011aed3277669d8543b488fdea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_120a721c5a2f19e49820c39d092c9856 = $(`&lt;div id=&quot;html_120a721c5a2f19e49820c39d092c9856&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1926&lt;/div&gt;`)[0];
#                 popup_375731011aed3277669d8543b488fdea.setContent(html_120a721c5a2f19e49820c39d092c9856);
#
#
#
#         marker_3a6d745c915c94f1b1058129cb30a471.bindPopup(popup_375731011aed3277669d8543b488fdea)
#         ;
#
#
#
#
#             var marker_7aa2154ab0771886653580ed8ad1d2cb = L.marker(
#                 [12.9067683, 77.5595021],
#                 {
# }
#             ).addTo(map_824e44ea768c1555be91e0c954fa4f62);
#
#
#         var popup_7e6edd74f69dc469e1d9784c7915da63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7840c0bb4e6ae6cfa638758917fba2a4 = $(`&lt;div id=&quot;html_7840c0bb4e6ae6cfa638758917fba2a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;195&lt;/div&gt;`)[0];
#                 popup_7e6edd74f69dc469e1d9784c7915da63.setContent(html_7840c0bb4e6ae6cfa638758917fba2a4);
#
#
#
#         marker_7aa2154ab0771886653580ed8ad1d2cb.bindPopup(popup_7e6edd74f69dc469e1d9784c7915da63)
#         ;
#
#
#
#
#             var marker_ddd5d3d5a9c5bb3b8ab5a076a5b0538c = L.marker(
#                 [12.9274413, 77.5155224],
#                 {
# }
#             ).addTo(map_82

# %%
# data cleanin in rate column

# %%
df.rate
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51712    3.6 /5
# 51713       NaN
# 51714       NaN
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 51696, dtype: object

# %%
df.rate.unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df.rate.isnull().sum()
# Out:
# np.int64(7754)

# %%
df.rate.isnull().sum()/len(df)*100 #14 percent of missing values from rate columns
# Out:
# np.float64(14.999226245744351)

# %%
df.dropna(subset='rate', inplace=True)

# %%
df.replace('NEW', '0', inplace=True)
df.replace('-', '0', inplace=True)

# %%
df.rate.unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', '0', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df['rating'] = df.rate.str.replace('/5', '').astype(float)

# %%
df.dtypes
# Out:
# url                             object
# address                         object
# name                            object
# online_order                    object
# book_table                      object
# rate                            object
# votes                            int64
# phone                           object
# location                        object
# rest_type                       object
# dish_liked                      object
# cuisines                        object
# approx_cost(for two people)     object
# reviews_list                    object
# menu_item                       object
# listed_in(type)                 object
# listed_in(city)                 object
# rating                         float64
# dtype: object

# %%
df.rating.unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 0. , 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2,
#        2.3, 4.8, 4.9, 2.1, 2. , 1.8])

# %%
# most highest rated restaurant

# %%
df.sort_values(by='rating', ascending=False)[['name', 'rating']][0:10]
# Out:
#                                  name  rating
# 21770       AB's - Absolute Barbecues     4.9
# 49627     Byg Brewski Brewing Company     4.9
# 38457          Belgian Waffle Factory     4.9
# 37843          Belgian Waffle Factory     4.9
# 49170     Byg Brewski Brewing Company     4.9
# 7888                         Flechazo     4.9
# 51042                        Flechazo     4.9
# 4944      Byg Brewski Brewing Company     4.9
# 11745          Belgian Waffle Factory     4.9
# 11504  Asia Kitchen By Mainland China     4.9

# %%
# location with best rating in average

# %%
df_rating = df.groupby('location').mean('rating').drop('votes', axis=1).reset_index().sort_values(by='rating', ascending=False)

# %%
df_rating.columns = ['Name', 'rating']

# %%
df_rating_merge = df_rating.merge(locations, on='Name')

# %%
basemap = genereteBaseMap()

# %%
df_rating
# Out:
#                                                  Name    rating
# 50         Lavelle Road , Bangalore, Karnataka, India  4.042886
# 80       St. Marks Road , Bangalore, Karnataka, India  4.017201
# 42  Koramangala 3rd Block , Bangalore, Karnataka, ...  3.978756
# 74          Sankey Road , Bangalore, Karnataka, India  3.965385
# 12        Church Street , Bangalore, Karnataka, India  3.963091
# ..                                                ...       ...
# 19      Electronic City , Bangalore, Karnataka, India  3.041909
# 7          Bommanahalli , Bangalore, Karnataka, India  2.926752
# 23               Hebbal , Bangalore, Karnataka, India  2.880000
# 60      North Bangalore , Bangalore, Karnataka, India  2.385714
# 87       West Bangalore , Bangalore, Karnataka, India  2.020000
#
# [92 rows x 2 columns]

# %%
HeatMap(df_rating_merge[['lat', 'lon', 'rating']]).add_to(basemap)

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a5a99601769d28522850f783cb5af0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a5a99601769d28522850f783cb5af0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a5a99601769d28522850f783cb5af0a = L.map(
#                 &quot;map_7a5a99601769d28522850f783cb5af0a&quot;,
#                 {
#                     center: [12.97, 77.59],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc0888cadc48eed2599b30123a0af8f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc0888cadc48eed2599b30123a0af8f3.addTo(map_7a5a99601769d28522850f783cb5af0a);
#
#
#             var heat_map_ab101d36e3d3ea0ba56b7a1cb95c1808 = L.heatLayer(
#                 [[12.972227072739638, 77.59866491535907, 4.042885771543086], [12.975801449285402, 77.60169240479877, 4.017201166180758], [12.9282918, 77.6254034, 3.978756476683938], [12.99378735117383, 77.58515115082001, 3.965384615384615], [12.975700066194872, 77.60208311450552, 3.9630909090909086], [12.9348429, 77.6189768, 3.901511969760605], [12.99099855, 77.58624795, 3.9010526315789473], [12.9274413, 77.5155224, 3.85], [12.96668780296818, 77.59874713313619, 3.8445723684210527], [13.0068, 77.5813, 3.839655172413793], [12.9327778, 77.6294052, 3.8143518518518515], [12.957998, 77.6037312, 3.8074074074074074], [12.982005047380023, 77.5992545090485, 3.7964285714285713], [12.9364846, 77.6134783, 3.7478420569329662], [12.9755